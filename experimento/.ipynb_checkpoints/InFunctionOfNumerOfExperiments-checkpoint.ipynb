# %%
# %pylab inline
import scipy.stats as stats
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
num_steps = 100
num_repetitions = 1000
num_experiments = 100

# %%
p_values = zeros(num_experiments)
t_stats = zeros(num_experiments)

mins = zeros(num_experiments)
maxs = zeros(num_experiments)
averages = zeros(num_experiments)

mins_t = zeros(num_experiments)
maxs_t = zeros(num_experiments)
averages_t = zeros(num_experiments)

minimum_p = 1000
maximum_p = -1000
minimum_p_array = zeros(num_repetitions)
maximum_p_array = zeros(num_repetitions)

for k in range(num_experiments):
    final_positions = zeros(num_repetitions)
    for i in range(num_repetitions):
        x = 0
        for j in range(num_steps):
            mu, sigma = 0, 0.05
            my_step = random.normal(mu, sigma)
            x = x + my_step;
        final_positions[i] = x
    mu_expected = 0
    mu_observed = mean(final_positions)
    s = std(final_positions)
    n = len(final_positions)
    t_stat = (mu_observed - mu_expected)/(s/sqrt(n))
    p_values[k] = stats.t.sf(abs(t_stat), n-1) + (1 - stats.t.sf(-abs(t_stat), n-1))

    mins[k] = min(p_values[:k+1])
    maxs[k] = max(p_values[:k+1])
    averages[k] = mean(p_values[:k+1])
    
    if p_values[k] < minimum_p:
        minimum_p = p_values[k]
        minimum_p_array = final_positions
    elif p_values[k] > maximum_p:
        maximum_p = p_values[k]
        maximum_p_array = final_positions

# %%
plot(mins)
plot(maxs)
plot(averages)
xlabel('Numero de Experimentos')
plt.legend(['minimo', 'maximo', 'promedio'], loc='upper right')

# %%
plot(mins_t)
plot(maxs_t)
plot(averages_t)
xlabel('Numero de Experimentos')
plt.legend(['minimo', 'maximo', 'promedio'], loc='upper right')

# %%
hist(minimum_p_array, bins=30)
print(mean(minimum_p_array))
print(minimum_p)
mu_expected = 0
mu_observed = mean(minimum_p_array)
s = std(minimum_p_array)
n = len(minimum_p_array)
t_stat = (mu_observed - mu_expected)/(s/sqrt(n))
print(t_stat)
print(s)
# Out:
# -0.140829416144
# 0.00295135017411
# -2.75906110837
# 1.61410602765

# %%
hist(maximum_p_array, bins=30)
print(mean(maximum_p_array))
print(maximum_p)
mu_expected = 0
mu_observed = mean(maximum_p_array)
s = std(maximum_p_array)
n = len(maximum_p_array)
t_stat = (mu_observed - mu_expected)/(s/sqrt(n))
print(t_stat)
print(s)
# Out:
# 0.000198297216002
# 0.498425919261
# 0.00394663306176
# 1.5888754957

# %%
hist(maximum_t_array, bins=30)
print(mean(maximum_t_array))
# Out:
# -0.140829416144

# %%
hist(minimum_t_array, bins=30)
print(mean(minimum_t_array))
# Out:
# 0.000198297216002
